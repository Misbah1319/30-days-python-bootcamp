# %% [markdown]
# <a href="https://colab.research.google.com/github/Misbah1319/30-days-python-bootcamp/blob/main/Python_Revision(day1_3).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
is_student=True
print(is_student)
print(type(is_student))
# Out:
# True
# <class 'bool'>

# %%
name=input("Enter your name:")
age =input("Enter your age:")
print(name, age )
# Out:
# Enter your name:Misbah
# Enter your age:22
# Misbah 22

# %%
#converting the age to integer
age=int(input("Enter your age:"+5))

print("Hello ", name," you will be ",age, "after 5 years")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3754493525.py in <cell line: 0>()
#       1 #converting the age to integer
# ----> 2 age=int(input("Enter your age:"+5))
#       3
#       4 print("Hello ", name," you will be ",age, "after 5 years")
#
# TypeError: can only concatenate str (not "int") to str

# %%
age=int(input("Enter your age:"))
new_age=age+5# we need to create a new variable cannot directly add the inetger to the value been recived by user : 1st taken as str
print("Hello", name, "you will be ", new_age,"after 5 years ")
# Out:
# Enter your age:22
# Hello Misbah you will be  27 after 5 years

# %%
#DAY-03
# Revising the if , else (Decision making)
print(10>5)
print(5>10)
print(10==10) # where as = is assignment operator & == is is equal to operator
print(10!=5)
# Out:
# True
# False
# True
# True

# %%
age=20
if age>18:
  print("You are eligible")
# Out:
# You are eligible

# %%
age=20
if age >22:
  print("You are eligible")# here it gives no otput bcoz the given input is not matching , and python is not been told to what to do if the condition doesnt meet

# %%
age=int(input("Say your age:"))
if age>=18:
  print("Yes, u r eligible for voting")
else:
  print("No, you are not eligible")
# Out:
# Say your age:18
# Yes, u r eligible for voting

# %%
#when multiple conditions come we use elif
marks=input("Enter your marks")
if marks >90:#> symbol should'nt be used in between the str and int
  print("A+")
elif marks >80:
  print("A")
elif marks>70:
  print("B+")
elif marks>60:
  print("B")
elif marks >50:
  print("C+")
elif marks>45:
  print("C")
else:
  print("Fail")
# Out:
# Enter your marks27
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3124379167.py in <cell line: 0>()
#       1 #when multiple conditions come we use elif
#       2 marks=input("Enter your marks")
# ----> 3 if marks >90:
#       4   print("A+")
#       5 elif marks >80:
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
#when multiple conditions come we use elif ; after every condition : if, esle & elif at end : should be mandatorily typed

marks=int(input("Enter your marks"))
if marks >90:
  print("A+")
elif marks >80:
  print("A")
elif marks>70:
  print("B+")
elif marks>60:
  print("B")
elif marks >50:
  print("C+")
elif marks>45:
  print("C")
else:
  print("Fail") # if we want multiple inputs and simultanous results we should use for & while loops-printed in ms
# Out:
# Enter your marks93
# A+

# %%
num=int(input("Enter your number :"))
if num >0:
  print("Number is positive")
elif num==0:
  print("Number is Zero")
else:
  print("Number is negative")
# Out:
# Enter your number :-2
# Number is negative

# %%
#in day 3 , thing that got out of mind was cannot use symbols(<,>,etc) directly betwwen the str and int
# need to 1st convert the type of variable
